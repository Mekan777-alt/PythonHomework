# %%
import pandas as pd

# %%
dataset = pd.read_csv("Books_Data_Clean.csv")
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# dtypes: float64(5), int64(4), object(6)
# memory usage: 125.5+ KB

# %%
missing_values = dataset.isnull().sum()

# %%
print(missing_values)
# Out:
# index                   0
# Publishing Year         1
# Book Name              23
# Author                  0
# language_code          53
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
dataset["Book Name"] = dataset["Book Name"].fillna('missing')

# %%
dataset["language_code"] = dataset["language_code"].fillna('missing')

# %%
dataset["Publishing Year"] = dataset["Publishing Year"].fillna("missing")

# %%
categorical_columns = dataset.select_dtypes(include=['object']).columns

for column in categorical_columns:
    unique_values = dataset[column].unique()
    value_counts = dataset[column].value_counts()
    print(f"\nУникальные значения для {column}:\n{unique_values}")
    print(f"\nПодсчеты значений для {column}:\n{value_counts}")
# Out:
# Уникальные значения для Book Name:
# ['Beowulf' 'Batman: Year One' 'Go Set a Watchman' ... 'The Maltese Falcon'
#  'Night Road' 'Tripwire']
#
# Подсчеты значений для Book Name:
# Book Name
# The Awakening                                                  2
# Persepolis                                                     2
# What Is the What: The Autobiography of Valentino Achak Deng    1
# Wintergirls                                                    1
# The Ruins of Gorlan                                            1
#                                                               ..
# é‹¼ã®éŒ¬é‡‘è¡“å¸« 1                                           1
# Guards! Guards!                                                1
# The Year of Magical Thinking                                   1
# We Need to Talk About Kevin                                    1
# Tripwire                                                       1
# Name: count, Length: 1045, dtype: int64
#
# Уникальные значения для Author:
# ['Unknown, Seamus Heaney'
#  "Frank Miller, David Mazzucchelli, Richmond Lewis, Dennis O'Neil"
#  'Harper Lee' 'David Sedaris' 'Laini Taylor' 'Victoria Aveyard'
#  'Charles Duhigg' 'John Berendt' 'Colleen Hoover'
#  'Frances Hodgson Burnett, Nancy Bond' 'Sarah Dessen' 'C.S. Lewis'
#  'Richelle Mead' 'Laura Ingalls Wilder, Garth Williams'
#  'Margery Williams Bianco, William   Nicholson' 'Robert M. Pirsig'
#  'H.G. Wells, Arthur C. Clarke' 'Sara Shepard' 'Don Freeman'
#  'Michael Pollan' 'Kate Atkinson' 'Nicholas Sparks' 'Stephen King'
#  'Diana Gabaldon' 'Kenneth Branagh, William Shakespeare'
#  'Jeffrey Eugenides' 'Charlaine Harris'
#  'Thomas Hardy, Tim Dolin, Margaret R. Higonnet'
#  'Gustave Flaubert, Margaret Mauldon, Malcolm Bowie, Mark Overstall'
#  'Norton Juster, Jules Feiffer' 'Brandon Sanderson' 'Ned Vizzini'
#  'Jojo Moyes' 'Vanessa Diffenbaugh'
#  'Frank Miller, Klaus Janson, Lynn Varley' 'James Patterson' 'Nick Hornby'
#  'Margaret Atwood' 'John Gray' 'Anthony Bourdain' 'Michael Crichton'
#  'Voltaire' 'Natalie Babbitt' 'Stephen King, Marie Milpois' 'P.D. Eastman'
#  'E.H. Gombrich' 'Marissa Meyer' 'Robert T. Kiyosaki' 'Becca Fitzpatrick'
#  'Lev Grossman' 'Tsugumi Ohba, Takeshi Obata' 'Libba Bray'
#  'Jonathan Safran Foer' 'Robert Ludlum' 'Tammara Webber'
#  'Charles Dickens, Jeremy Tambling' 'Sherman Alexie, Ellen Forney'
#  "Mikhail Bulgakov, Katherine Tiernan O'Connor, Diana Burgin, Ellendea Proffer"
#  'Ursula K. Le Guin' 'Kate DiCamillo, Chris Sheban' 'John Knowles'
#  'John Grisham'
#  'Miguel de Cervantes Saavedra, Roberto GonzÃ¡lez EchevarrÃ\xada, John Rutherford'
#  'Robin Hobb' 'Douglas Adams' 'Lauren Kate' 'Beatrix Potter'
#  'C.S. Lewis, Pauline Baynes' 'Susanna Kaysen' 'Chelsea Handler'
#  'Richard Bach, Russell Munson' 'Cassandra Clare'
#  'Robert Munsch, Sheila McGraw' 'Daniel James Brown'
#  'J.R.R. Tolkien, Christopher Tolkien, Ted Nasmith' 'Kate Morton'
#  'Franz Kafka, Edwin Muir, Willa Muir, Max Brod' 'Jodi Picoult'
#  'Piper Kerman' 'Arthur Conan Doyle, Anne Perry' 'Daniel Kahneman'
#  'Marion Zimmer Bradley' 'Judy Blume' 'Chris Bohjalian'
#  'Chris Van Allsburg' 'Jon Scieszka, Lane Smith' 'Tom Clancy'
#  'Paulo Coelho, Margaret Jull Costa' 'Sheryl Sandberg, Nell Scovell'
#  'Tahereh Mafi' 'Robert A. Heinlein' 'Sophie Kinsella'
#  'Jostein Gaarder, Paulette MÃ¸ller' 'Mark Cotta Vaz' 'Ray Bradbury'
#  'Jennifer Egan' 'Johanna Spyri, Angelo  Rinaldi, Beverly Cleary'
#  'Ken Follett' 'P.C. Cast, Kristin Cast' 'Alex Flinn'
#  'Geoffrey Chaucer, Nevill Coghill' 'Emily Giffin' 'Christopher Paolini'
#  'Haruki Murakami, Jay Rubin, Philip Gabriel' 'Harriet Beecher Stowe'
#  'Gaston Leroux, Alexander Teixeira de Mattos'
#  'JosÃ© Saramago, Giovanni Pontiero' 'Jonathan Franzen' 'Ally Condie'
#  'Ally Carter' 'Aravind Adiga' 'Barack Obama' 'Judith Viorst, Ray Cruz'
#  'Jhumpa Lahiri' 'Howard Zinn' 'Truman Capote' 'Justin Cronin'
#  'Neil Gaiman' 'Celeste Ng' 'Isabel Allende, Magda Bogin'
#  'Agatha Christie, Î¡Î¿Î¶Î¯Ï„Î± Î£ÏŽÎºÎ¿Ï…' 'Agatha Christie'
#  'Chimamanda Ngozi Adichie' 'Sylvia Day' 'Christopher McDougall'
#  'Gabrielle Zevin' 'Ludwig Bemelmans' 'Napoleon Hill' 'Susanna Clarke'
#  'Rick Riordan' 'Michael  Grant' 'David McCullough' 'Jon Krakauer'
#  'Jess Walter' 'Kristin Hannah' 'Robert Galbraith, J.K. Rowling'
#  'Anne Rice' 'Ann Patchett' 'Matthew Quick' 'Jules Verne, Anthony Bonner'
#  'Philippa Gregory' 'Virginia Woolf, Maureen Howard'
#  'Jonas Jonasson, Rod Bradbury' 'John Irving'
#  'Richard Bachman, Stephen King'
#  'Jules Verne, Michael Glencross, Brian W. Aldiss' 'Sharon Creech'
#  'J.D. Salinger' 'Julie Powell' 'Neal Shusterman' 'Marie Lu'
#  'William Shakespeare' 'Arthur Miller' 'Kate Egan' 'William Faulkner'
#  'Eckhart Tolle' 'Tite Kubo' 'Allie Brosh' 'Robert Jordan'
#  'Gregory David Roberts' 'Stephen King, Ned Dameron' 'Jeffery Deaver'
#  'Bernhard Schlink, Carol Brown Janeway' 'Bill Martin Jr., Eric Carle'
#  'Dan Simmons' 'John Steinbeck' 'William Peter Blatty' 'Stephenie Meyer'
#  'David Guterson' 'Alex Haley' 'Alan Moore, Brian Bolland, Tim Sale'
#  'Ralph Ellison' 'Ishmael Beah' "Robert C. O'Brien" 'Melissa Bank'
#  'Hugh Howey' 'Christopher Moore' 'Jenny  Lawson' 'Scott Lynch'
#  'Garth Nix' 'Jennifer L. Armentrout' 'Sarah J. Maas' "Bryan Lee O'Malley"
#  'Jeannette Walls' 'Terry Pratchett' 'Julie Kagawa' 'Larry McMurtry'
#  'Mary Roach' 'Orson Scott Card' 'Thomas Keneally' 'Toni Morrison'
#  'Malcolm X, Alex Haley'
#  'Neil Gaiman, Sam Kieth, Mike Dringenberg, Malcolm Jones III, Todd Klein, Karen  Berger'
#  'Laura Hillenbrand' 'Dennis Lehane' 'Arthur Conan Doyle'
#  'William Shakespeare, Roma Gill' 'Erik Larson' 'Plato, Desmond Lee'
#  'Patti Smith' 'Phaidon Press' 'Jane Green' 'Victor Hugo, Walter J. Cobb'
#  'Rohinton Mistry' 'Bill Watterson, G.B. Trudeau' 'Scott Westerfeld'
#  'Kate Chopin' 'Mitch Albom' 'Shel Silverstein' 'Justin Halpern'
#  'Irvine Welsh, Eric Lindor Fall' 'Isaac Asimov' 'Miguel Ruiz'
#  'Jacob Grimm, Wilhelm Grimm, Josef Scharl, Padraic Colum, Joseph Campbell, Margaret Raine Hunt, James Stern'
#  'E.L. Konigsburg' 'Samantha Young'
#  'Francis Chan, Danae Yankoski, Chris Tomlin' 'Dr. Seuss' 'Dean Koontz'
#  'Helen Keller' 'Jonathan Tropper' 'Seth Grahame-Smith'
#  'Natsuki Takaya, Alethea Nibley, Athena Nibley'
#  'Stephen King, Dave McKean' 'Dave Eggers' 'Brian Selznick'
#  'Aldous Huxley, Christopher Hitchens' 'Bisco Hatori' 'Mary Kubica'
#  'Abbi Glines' 'Rainbow Rowell' 'Cormac McCarthy' 'Hilary Mantel'
#  'Diana Wynne Jones' 'Stephen King, William Olivier Desmond'
#  'Henry David Thoreau' 'Kazuo Ishiguro' 'Julian Barnes' 'Sue Grafton'
#  'Sophocles, J.E. Thomas' 'Lisa See' 'Kenneth Grahame, Gillian Avery'
#  'Jenny Han' 'Marjane Satrapi, Mattias Ripa' 'E.M. Forster'
#  'Kody Keplinger' 'J.D. Robb' 'Masashi Kishimoto, Katy Bridges'
#  'Rachel Joyce' 'David Levithan'
#  'William Shakespeare, Robert          Jackson, Barbara A. Mowat, Paul Werstine'
#  'James Clavell' 'J.R. Ward' 'E.L. James'
#  'Bill Martin Jr., John Archambault, Lois Ehlert' 'Raina Telgemeier'
#  'George Orwell, Christopher Hitchens' 'Jacquelyn Mitchard' 'Amy Tan'
#  'Louise Rennison' 'Robin Sloan' 'V.C. Andrews'
#  'Paul Kalanithi, Abraham Verghese' 'Jerry Spinelli' 'Chuck Palahniuk'
#  'Lois Lowry' 'Ellen Raskin' 'Pierce Brown' 'Brent Weeks'
#  'Barbara Kingsolver' 'Jamie McGuire' 'Sam McBratney, Anita Jeram'
#  'Stephen King, John D. MacDonald' 'Peter Benchley' 'Nicole Krauss'
#  'Astrid Lindgren, Lauren Child, Florence Lamborn, Nancy Seligsohn'
#  'Muriel Barbery, Alison Anderson' 'Doris Kearns Goodwin, Suzanne Toren'
#  'Albert Camus, Stuart Gilbert' 'Lemony Snicket, Brett Helquist'
#  'Susannah Cahalan' 'Melissa Marr' 'H.A. Rey'
#  'Michael Ende, Ralph Manheim, Roswitha Quadflieg' 'Sylvia Nasar'
#  'Upton Sinclair, Earl Lee, Kathleen DeGrave' 'Kelley Armstrong'
#  'Oliver Sacks' 'Ransom Riggs' 'Andre Dubus III' 'M.R. Carey'
#  'Crockett Johnson' 'Jim Butcher' 'Malcolm Gladwell'
#  'Hiromu Arakawa, Akira Watanabe' 'Joan Didion' 'Lionel Shriver'
#  'Arthur C. Clarke' 'Edith Wharton, Maureen Howard' 'Richard Dawkins'
#  'Geraldine Brooks' 'Michael Connelly' 'Ayn Rand' 'Sylvain Reynard'
#  'Judi Barrett, Ron Barrett' 'Helen Simonson' 'Nora Roberts' 'John Scalzi'
#  'Janet Evanovich'
#  'Irma S. Rombauer, Marion Rombauer Becker, Ethan Becker' 'Joe Haldeman'
#  'Stephen King, Bettina Blanch Tyroller' 'Azar Nafisi' 'Joe Abercrombie'
#  'Eoin Colfer' 'Annie Proulx' 'Marie KondÅ\x8d, Cathy Hirano'
#  'Jennifer Niven, Ù\x81Ø±Ø§Ù†Ú© Ù…Ø¹Ù†ÙˆÛŒ' 'Kathy Reichs' 'Michael Scott'
#  'Isabel Allende, Margaret Sayers Peden' 'Jessica Knoll' 'Ellen Hopkins'
#  'Maggie Stiefvater' 'Richard Matheson' 'Elizabeth Strout'
#  'Lena Dunham, Joana Avillez' 'James C. Collins' 'Kristin Cashore'
#  'Samuel Beckett' 'Jack London' 'Stephen King, Bernie Wrightson'
#  'Philip Pullman' 'J.A. Redmerski' 'Kimberly McCreight'
#  'Michael Cunningham' 'Alice Clayton' 'James Dashner' 'Susan Ee'
#  'Richard Russo' 'Jandy Nelson' 'Catherine Hardwicke' 'Richard Feynman'
#  'L.M. Montgomery' 'James Joyce, Seamus Deane'
#  'Robert Jordan, Brandon Sanderson' 'George Eliot, Michel Faber'
#  'J.R.R. Tolkien' 'S.C. Stephens' 'Scott Turow' 'Stacy Schiff'
#  'Thomas L. Friedman' 'Marcus Pfister, J. Alison James' 'Jules Verne'
#  'Gretchen Rubin' 'Philip K. Dick' 'Vincent Bugliosi, Curt Gentry'
#  'Robert Kapilow, Dr. Seuss' 'Dante Alighieri, Anthony M. Esolen'
#  'Deborah Harkness' 'Patricia Briggs' 'Melissa de la Cruz' 'Caleb Carr'
#  'Ta-Nehisi Coates' 'John Milton, John      Leonard' 'Michael   Lewis'
#  'Patrick Ness, Jim Kay, Siobhan Dowd' 'Frederick Forsyth'
#  'Jason Fried, David Heinemeier Hansson'
#  'Stephenie Meyer, Ilyana Kadushin, Matt Walters' 'Carol Rifka Brunt'
#  'James Herriot' 'Michelle Hodkin' 'Emmuska Orczy'
#  'Jon Stone, Michael J. Smollin' 'Leigh Bardugo'
#  'Herman Koch, Sam Garrett' 'Carl Sagan' 'Stephanie Perkins' 'Zadie Smith'
#  'Chris Kyle, Scott McEwen, Jim DeFelice' 'Pittacus Lore' 'Meg Wolitzer'
#  'Bill Watterson' 'Better Homes and Gardens'
#  'Hermann Hesse, Basil Creighton' 'Tess Gerritsen'
#  'Kate DiCamillo, Timothy Basil Ering'
#  'Barbara Kingsolver, Steven L. Hopp, Camille Kingsolver, Richard A. Houser'
#  'Alan Bradley' 'Donald Miller' 'Liane Moriarty'
#  'Brian K. Vaughan, Fiona Staples' 'Chad Harbach' 'Ernest Hemingway'
#  'Brandon Mull' 'Walter Isaacson' 'Mildred D. Taylor'
#  'Seth Grahame-Smith, Jane Austen'
#  'Fyodor Dostoyevsky, Constance Garnett, Alan Myers, Joseph Frank, Anna Brailovsky'
#  'Jeff Kinney' 'Mindy Kaling' 'Veronica Roth'
#  'Aziz Ansari, Eric Klinenberg' 'Katherine Applegate, Patricia Castelao'
#  'Sebastian Junger' 'Patrick Ness' 'Jim Fergus'
#  'Stephen King, Darrel Anderson' 'Salman Rushdie' 'Max Brooks'
#  'Margaret Peterson Haddix' 'Elizabeth George Speare' 'Kiera Cass'
#  'Wilkie Collins, Matthew Sweet' 'James McBride'
#  'Steven D. Levitt, Stephen J. Dubner' 'Karen Marie Moning'
#  'Terry Goodkind' 'William Makepeace Thackeray, John Carey'
#  'Kurt Vonnegut Jr.' 'Stephen King, Dominique Dill'
#  "Cynthia D'Aprix Sweeney"
#  'Bill Willingham, Lan Medina, Steve Leialoha, Craig Hamilton, James Jean'
#  'David    Allen' 'James Redfield' 'Huntley Fitzpatrick'
#  'Haruki Murakami, Philip Gabriel' 'Alice Sebold' 'Virginia Woolf'
#  'Chetan Bhagat' 'Laurell K. Hamilton' 'Markus Zusak'
#  'Thomas Hardy, Rosemarie Morgan, Shannon Russell' 'Mark Z. Danielewski'
#  'Patricia Cornwell' 'Willa Cather' 'Susan Beth Pfeffer'
#  'Jon Stewart, Ben Karlin, David Javerbaum, Rich Bloomquist, Steve Bodow, Tim Carvell, Eric Drysdale, J.R. Havlan, Scott Jacobson, Tom Johnson, Rob Kutner, Chris Regan, Jason Reich, Jason Ross, Stephen Colbert, Samantha Bee, Rob Corddry, Brendan Hay, Ed Helms'
#  'Don Piper, Cecil Murphey'
#  'Lao Tzu, Gia-Fu Feng, Jane English, Chungliang Al Huang, Rowena Pattee Kryder, Toinette Lippe'
#  'Jeffrey Archer' 'Augusten Burroughs' 'Frank Herbert' 'Jennifer Weiner'
#  'Hans Christian Andersen, Lily Owens, Arthur Rackham, Hans Richter'
#  'Friedrich Nietzsche, Walter Kaufmann' 'Elizabeth Gaskell, Alan Shelston'
#  'Jaycee Dugard' 'Amish Tripathi' 'Lauren Oliver'
#  'Aesop, Laura Harris, Laura Gibbs' 'Matsuri Hino, Tomo Kimura'
#  'Anne McCaffrey, Teodor PanasiÅ„ski' 'John D. Rateliff, J.R.R. Tolkien'
#  'Joanne Harris' 'Jay Anson' 'Michael Ondaatje'
#  'James Joyce, Jeri Johnson' 'Colum McCann' 'Harlan Coben'
#  'Rachel Hawkins' 'Austin Kleon' 'Neal Stephenson' 'Christina Lauren'
#  'Joyce Carol Oates' 'Scott McCloud' 'Kami Garcia, Margaret Stohl'
#  'Jon Ronson' 'David Baldacci' 'Jonathan Stroud'
#  'Stephen Colbert, Richard Dahm, Paul Dinello, Allison Silverman, Michael Brumm, Eric Drydale, Rob Dubbin, Glenn Eichler, Peter Grosz, Peter Gwinn, Jay Katsir, Laura Krafft, Frank Lesser, Tom Purcell'
#  'Kenneth H. Blanchard, Spencer Johnson' 'Leon Uris' 'Ursula Hegi'
#  'Raymond Chandler' 'Ellen DeGeneres' 'Eowyn Ivey'
#  'J. Lynn, Jennifer L. Armentrout'
#  'Dante Alighieri, Allen Mandelbaum, Eugenio Montale'
#  'Benjamin Hoff, Ernest H. Shepard' 'Sarah Dunant'
#  'David Lagercrantz, Stieg Larsson, George Goulding' 'Emma Cline'
#  'Shannon Hale' 'Isaac Marion' 'Mark Twain, Everett H. Emerson'
#  'Elif Shafak, Ø¥Ù„ÙŠÙ\x81 Ø´Ø§Ù\x81Ø§Ù‚, Ø§Ø±Ø³Ù„Ø§Ù† Ù\x81ØµÛŒØ\xadÛŒ, Ù…Ø\xadÙ…Ø¯ Ø¯Ø±ÙˆÙŠØ´'
#  'Hajime Isayama, Sheldon Drzka' 'F. Scott Fitzgerald' 'Olive Ann Burns'
#  'Tennessee Williams' 'Elena Ferrante, Ann Goldstein' 'Timothy Ferriss'
#  'Robin S. Sharma' 'Amor Towles' 'Larry Niven' 'Ruta Sepetys'
#  'Andrew Clements, Brian Selznick' 'Louise Erdrich' "Madeleine L'Engle"
#  'Hanya Yanagihara' 'Brian K. Vaughan, Pia Guerra, JosÃ© MarzÃ¡n Jr.'
#  'Anne Tyler, Jennifer Bassett' 'Benjamin Alire SÃ¡enz' 'H.G. Wells'
#  'Haruki Murakami, Alfred Birnbaum' 'Paulo Coelho, Alan R. Clarke'
#  'Johann David Wyss, Scott McKowen, Arthur Pober' 'Jennifer Probst'
#  'Watty Piper, Doris Hauman, George Hauman' 'Karen Joy Fowler'
#  'James Joyce' 'Alan Brennert' 'Frank E. Peretti' 'Jessica Sorensen'
#  'Lauren Groff' 'E.B. White, Garth Williams' 'Brian Greene'
#  'Janell Cannon' 'Nancy Horan' 'Janet Evanovich, Lorelei King'
#  'Flora Rheta Schreiber' 'Rosamunde Pilcher'
#  'Gabriel GarcÃ\xada MÃ¡rquez, Gregory Rabassa'
#  'Ronald Holt, Arthur Conan Doyle' "Bill O'Reilly, Martin Dugard"
#  'John Flanagan' 'Laurie Halse Anderson' 'Ira Levin'
#  'Stephen King, Peter Straub' 'Jack Kerouac' 'Katherine Boo'
#  'P.L. Travers, Mary Shepard' 'Sandra Cisneros' 'David Benioff'
#  'Jeaniene Frost' 'Roald Dahl, Quentin Blake'
#  'James Patterson, Peter de Jonge' 'James S.A. Corey' 'Art Spiegelman'
#  'Ezra Jack Keats' 'Richard   Preston' 'Elizabeth Gilbert' 'Lynne Truss'
#  'Kim Harrison' 'Clement C. Moore, Jan Brett' 'Cynthia Hand' 'Lee Strobel'
#  'Carl Hiaasen' 'Virgil, Robert Fitzgerald' 'Junot DÃ\xadaz'
#  'Haruki Murakami, Jay Rubin' 'Daniel Quinn' 'Katie McGarry'
#  'Kennilworthy Whisp, J.K. Rowling' 'Harry Allard, James  Marshall'
#  'Stephen King, Jerry N. Uelsmann' 'Trenton Lee Stewart, Carson Ellis'
#  'Christopher Hitchens' 'Jennifer E. Smith' 'Tom Robbins' 'Jenna Blum'
#  'Beth Revis' 'M. Scott Peck' 'Gertrude Chandler Warner, L. Kate Deal'
#  'A.S.A. Harrison' 'Caitlin Moran' 'Keith Richards' 'Anita Shreve'
#  'Don DeLillo' 'Stephen E. Ambrose' 'Charles Darwin' 'Craig Thompson'
#  'David Wroblewski' 'Christina Schwarz' 'Charles Bukowski'
#  'Arthur Conan Doyle, Kyle Freeman' 'EiichirÅ\x8d Oda, Andy Nakatani'
#  'Peter S. Beagle' 'Angie Sage' 'Tana French' 'Rudyard Kipling'
#  'Terry Hayes' 'Allen Ginsberg, William Carlos Williams' 'Richard Carlson'
#  'Adam Mansbach, Ricardo CortÃ©s' 'TÃ©a Obreht' 'Maria V. Snyder'
#  'Anonymous, Joseph Smith Jr.' 'Karin Slaughter'
#  'Yana Toboso, Tomo Kimura' 'Robert Louis Stevenson, Robert Mighall'
#  'Emily Seife' 'Peter V. Brett' 'John Bunyan' 'Lee Child'
#  'Fyodor Dostoyevsky, Andrew R. MacAndrew, Ben Marcus' 'Carson McCullers'
#  'Rick Yancey' 'T.H. White' 'Christopher Paul Curtis' 'Alison Bechdel'
#  'Dan Ariely' 'Ø£Ø\xadÙ…Ø¯ Ù…Ø±Ø§Ø¯' 'Lynne Reid Banks' 'Jesse Andrews'
#  'Simon Winchester' 'James Patterson, Andrew Gross' 'Jasper Fforde'
#  'Faye Perozich, Anne Rice, John Bolton, Daerick GrÃ¶ss'
#  'Louis Sachar, Adam McCauley' 'Dalai Lama XIV, Howard C. Cutler'
#  'David Mitchell' 'Anna Quindlen'
#  'L.J. Smith, Kevin Williamson, Julie Plec' 'Cornelia Funke, Anthea Bell'
#  'Chuck Klosterman' 'Evelyn Waugh' 'Jessie Burton'
#  'Margaret Weis, Tracy Hickman' 'Julia Cameron' 'Joe Hill'
#  'Robert K. Massie' 'Marcus Luttrell, Patrick Robinson' 'Richard Wright'
#  'Veronica Rossi' 'Eric Ries' 'Lauren Weisberger' 'David Eddings'
#  'Roberto Aguirre-Sacasa, Stephen King, Mike Perkins, Laura       Martin'
#  'William L. Shirer' 'Jeff Smith, Steve Hamaker'
#  'Kami Garcia, Margaret Stohl, Paz Pruneda' 'Brian Jacques'
#  'Karl Marx, Friedrich Engels, Gareth Stedman Jones' 'Ruth Ware'
#  'James Fenimore Cooper' 'William Styron' 'Bruce H. Wilkinson'
#  'Karen Thompson Walker' "Julia Child, Alex Prud'Homme" 'Graeme Simsion'
#  'Wendelin Van Draanen' 'Travis Bradberry, Jean Greaves, Patrick Lencioni'
#  'Robert McCloskey' 'Douglas Preston, Lincoln Child' 'Bill Bryson'
#  'Robert Kirkman' 'Nicola Yoon, David Yoon' 'George Bernard Shaw'
#  'Helen Fielding' 'Louis de BerniÃ¨res' 'Adam Johnson'
#  'Marjane Satrapi, Mattias Ripa, Blake Ferris, Anjali Singh' 'Chaim Potok'
#  'Irving Stone, ×©×ž×•×\x90×œ ×©×\xa0×™×¦×¨'
#  'Carlos Ruiz ZafÃ³n, Lucia Graves' 'Cecelia Ahern'
#  'Peggy Parish, Fritz Siebel' 'Jodi Ellen Malpas' 'W. Bruce Cameron'
#  'Sabaa Tahir' 'Helene Wecker'
#  'Ø£Ø\xadÙ„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi'
#  'Charles Dickens, Nicola Bradbury, Hablot Knight Browne'
#  'Esphyr Slobodkina' 'Tamora Pierce' 'Audrey Niffenegger' 'Anita Diamant'
#  'James Ellroy' 'Lewis Carroll, John Tenniel, Peter Glassman' 'Jung Chang'
#  'Guillermo del Toro, Chuck Hogan' 'Emily Dickinson, Thomas H. Johnson'
#  'Fred Gipson' 'Steve Martin' 'Frank Warren' 'George R.R. Martin'
#  'Mary Norton, Beth Krush, Joe Krush' 'Alexandra Bracken'
#  'Norman Vincent Peale' 'Edith Wharton, Nina Bawden'
#  'Hiro Mashima, William Flanagan' 'Patrick Rothfuss, Nate  Taylor'
#  'Solomon Northup' 'Nathaniel Philbrick' 'Ayaan Hirsi Ali'
#  'Nassim Nicholas Taleb' 'Aleksandr Solzhenitsyn, H.T. Willetts'
#  'Walter M. Miller Jr.' 'Colm TÃ³ibÃ\xadn' 'Lauren DeStefano' 'J.D. Vance'
#  'Stephen Crane' 'Randall Munroe' 'Steven Erikson' 'Paulo Coelho'
#  'Suzanne Collins' 'Anne Tyler' 'Colson Whitehead' 'Cora Carmack'
#  'J.M. Coetzee' 'A.A. Milne, Ernest H. Shepard' 'Sue Monk Kidd'
#  'Arnold Lobel' 'B.A. Paris' 'Michael Shaara' 'Sharon M. Draper'
#  'Amanda Hocking'
#  'Boris Pasternak, Max Hayward, Manya Harari, John Bayley' 'Blake Crouch'
#  'P.D. James' 'Edith Wharton' 'Jane Hamilton, Frank  Muller, C.J. Critt'
#  'O. Henry, Lisbeth Zwerger' 'Tom Wolfe'
#  'William S. Burroughs, James Grauerholz, Barry  Miles'
#  'Neil Gaiman, Kelley Jones, Charles Vess, Colleen Doran, Malcolm Jones III, Steve Erickson'
#  'Ursula K. Le Guin, Lech JÄ™czmyk'
#  'John Green, Maureen Johnson, Lauren Myracle' 'Atul Gawande'
#  'Henrik Ibsen, Michael   Meyer' 'James A. Michener' 'Richard Yates'
#  'Rachel Cohn, David Levithan' 'Tom Stoppard, Henry Popkin' 'Alex Garland'
#  'Beth Hoffman, Jenna Lamia' 'Beverly Cleary' 'Raymond E. Feist'
#  'Jennifer Crusie' 'Nelson Mandela' 'Bryce Courtenay' 'Dashiell Hammett']
#
# Подсчеты значений для Author:
# Author
# Stephen King                                              29
# John Grisham                                              13
# Jodi Picoult                                              11
# Charlaine Harris                                          10
# Jim Butcher                                               10
#                                                           ..
# Nora Roberts                                               1
# John Scalzi                                                1
# Irma S. Rombauer, Marion Rombauer Becker, Ethan Becker     1
# Joe Haldeman                                               1
# Dashiell Hammett                                           1
# Name: count, Length: 735, dtype: int64
#
# Уникальные значения для language_code:
# ['en-US' 'eng' nan 'spa' 'en-GB' 'fre' 'en-CA' 'nl' 'ara']
#
# Подсчеты значений для language_code:
# language_code
# eng      737
# en-US    234
# en-GB     30
# en-CA      7
# fre        4
# spa        2
# ara        2
# nl         1
# Name: count, dtype: int64
#
# Уникальные значения для Author_Rating:
# ['Novice' 'Intermediate' 'Famous' 'Excellent']
#
# Подсчеты значений для Author_Rating:
# Author_Rating
# Intermediate    625
# Excellent       362
# Famous           53
# Novice           30
# Name: count, dtype: int64
#
# Уникальные значения для genre:
# ['genre fiction' 'fiction' 'nonfiction' 'children']
#
# Подсчеты значений для genre:
# genre
# genre fiction    822
# nonfiction       171
# fiction           62
# children          15
# Name: count, dtype: int64
#
# Уникальные значения для Publisher :
# ['HarperCollins Publishers' 'Amazon Digital Services,  Inc.'
#  'Hachette Book Group' 'Penguin Group (USA) LLC' 'Random House LLC'
#  'Simon and Schuster Digital Sales Inc' 'Macmillan'
#  'HarperCollins Publishing' 'HarperCollins Christian Publishing']
#
# Подсчеты значений для Publisher :
# Publisher
# Amazon Digital Services,  Inc.          600
# Random House LLC                        120
# Penguin Group (USA) LLC                 108
# HarperCollins Publishers                 71
# Hachette Book Group                      66
# Simon and Schuster Digital Sales Inc     56
# Macmillan                                41
# HarperCollins Publishing                  4
# HarperCollins Christian Publishing        4
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
numeric_columns = dataset.select_dtypes(include=['int', 'float']).columns

for column in numeric_columns:
    plt.figure(figsize=(8, 5))
    plt.hist(dataset[column], bins=20, edgecolor='black')
    plt.title(f'Histogram for {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
dataset_head = dataset.head()
dataset_head
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
# 2        Novice                 3.31              138669  genre fiction
# 3  Intermediate                 4.04              150898        fiction
# 4  Intermediate                 4.04              198283  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
# 2      47795.0            28677.0        8.69           3
# 3      41250.0            24750.0        7.50           3
# 4      37952.5            22771.5        7.99           4
#
#                        Publisher   units sold
# 0        HarperCollins Publishers        7000
# 1        HarperCollins Publishers        6250
# 2  Amazon Digital Services,  Inc.        5500
# 3             Hachette Book Group        5500
# 4         Penguin Group (USA) LLC        4750

# %% [markdown]
# Вывод: Просмотр первых строк дает представление о структуре и содержании датасета.

# %%
numeric_stats = dataset.describe()
numeric_stats
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# std     3936.924240        2257.596743     3.559919   369.849830  15370.571306
# min      104.940000           0.000000     0.990000     1.000000    106.000000
# 25%      372.465000           0.000000     1.990000   287.500000    551.250000
# 50%      809.745000         273.078000     3.990000   595.500000   3924.000000
# 75%     1487.957500         721.180500     6.990000   932.500000   5312.250000
# max    47795.000000       28677.000000    33.860000  1273.000000  61560.000000

# %% [markdown]
# Вывод: Статистика числовых переменных помогает понять распределение данных и их характеристики.

# %%
unique_values_column = dataset['Book Name'].unique()
unique_values_column
# Out:
# array(['Beowulf', 'Batman: Year One', 'Go Set a Watchman', ...,
#        'The Maltese Falcon', 'Night Road', 'Tripwire'], dtype=object)

# %% [markdown]
# Вывод: Просмотр уникальных значений в категориальном столбце помогает понять разнообразие данных в этом столбце.

# %%
filtered_data = dataset[dataset['Book_ratings_count'] > 100]
filtered_data
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                            Harper Lee           eng
# 3                                         David Sedaris         en-US
# 4                                          Laini Taylor           eng
# ...                                                 ...           ...
# 1065                                       John Grisham           eng
# 1066                                    Bryce Courtenay           eng
# 1067                                   Dashiell Hammett           eng
# 1068                                     Kristin Hannah         en-US
# 1069                                          Lee Child           eng
#
#      Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0           Novice                 3.42              155903  genre fiction
# 1     Intermediate                 4.23              145267  genre fiction
# 2           Novice                 3.31              138669  genre fiction
# 3     Intermediate                 4.04              150898        fiction
# 4     Intermediate                 4.04              198283  genre fiction
# ...            ...                  ...                 ...            ...
# 1065  Intermediate                 3.52               37379     nonfiction
# 1066     Excellent                 4.34               57312  genre fiction
# 1067  Intermediate                 3.92               58742  genre fiction
# 1068     Excellent                 4.17               58028  genre fiction
# 1069     Excellent                 4.07               55251  genre fiction
#
#       gross sales  publisher revenue  sale price  sales rank  \
# 0        34160.00          20496.000        4.88           1
# 1        12437.50           7462.500        1.99           2
# 2        47795.00          28677.000        8.69           3
# 3        41250.00          24750.000        7.50           3
# 4        37952.50          22771.500        7.99           4
# ...           ...                ...         ...         ...
# 1065       104.94             62.964        0.99        1268
# 1066       846.94            508.164        7.99        1270
# 1067       846.94            508.164        7.99        1271
# 1068       104.94             62.964        0.99        1272
# 1069       316.94              0.000        2.99        1273
#
#                           Publisher   units sold
# 0           HarperCollins Publishers        7000
# 1           HarperCollins Publishers        6250
# 2     Amazon Digital Services,  Inc.        5500
# 3                Hachette Book Group        5500
# 4            Penguin Group (USA) LLC        4750
# ...                              ...         ...
# 1065  Amazon Digital Services,  Inc.         106
# 1066                Random House LLC         106
# 1067             Hachette Book Group         106
# 1068  Amazon Digital Services,  Inc.         106
# 1069  Amazon Digital Services,  Inc.         106
#
# [1070 rows x 15 columns]

# %% [markdown]
# Вывод: Фильтрация данных по условию полезна для выделения интересующих нас подмножеств данных.

# %%
grouped_counts = dataset.groupby('Author').size().reset_index(name='counts')
grouped_counts
# Out:
#                                               Author  counts
# 0                      A.A. Milne, Ernest H. Shepard       1
# 1                                    A.S.A. Harrison       1
# 2                                        Abbi Glines       2
# 3                                       Adam Johnson       1
# 4                     Adam Mansbach, Ricardo CortÃ©s       1
# ..                                               ...     ...
# 730                                   William Styron       1
# 731                         Yana Toboso, Tomo Kimura       1
# 732                                      Zadie Smith       1
# 733  Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi       1
# 734                                Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯       1
#
# [735 rows x 2 columns]

# %% [markdown]
# Вывод: Группировка данных позволяет подсчитать количество записей по категориальному столбцу.

# %%
mean_by_category = dataset.groupby('Author_Rating')['Book_ratings_count'].mean()
mean_by_category
# Out:
# Author_Rating
# Excellent        82905.889503
# Famous           97414.301887
# Intermediate    101946.995200
# Novice           88728.166667
# Name: Book_ratings_count, dtype: float64

# %% [markdown]
# Вывод: Этот запрос помогает выявить средние значения числовой переменной для каждой категории.

# %%
max_by_category = dataset.groupby('Author')['sales rank'].max()
max_by_category
# Out:
# Author
# A.A. Milne, Ernest H. Shepard                      1199
# A.S.A. Harrison                                     897
# Abbi Glines                                         884
# Adam Johnson                                       1097
# Adam Mansbach, Ricardo CortÃ©s                      930
#                                                    ...
# William Styron                                     1059
# Yana Toboso, Tomo Kimura                            960
# Zadie Smith                                         524
# Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi    1107
# Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯                                   984
# Name: sales rank, Length: 735, dtype: int64

# %% [markdown]
# Вывод: Этот запрос показывает максимальные значения числовой переменной для каждой категории.

# %%
mean_by_two_categories = dataset.groupby(['Author', 'Book Name'])['Book_ratings_count'].mean().reset_index(name='mean_value')
mean_by_two_categories
# Out:
#                                                Author  \
# 0                       A.A. Milne, Ernest H. Shepard
# 1                                     A.S.A. Harrison
# 2                                         Abbi Glines
# 3                                         Abbi Glines
# 4                                        Adam Johnson
# ...                                               ...
# 1042                                   William Styron
# 1043                         Yana Toboso, Tomo Kimura
# 1044                                      Zadie Smith
# 1045  Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi
# 1046                                Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯
#
#                          Book Name  mean_value
# 0         The House at Pooh Corner     69102.0
# 1                  The Silent Wife     60323.0
# 2     Fallen Too Far (Too Far, #1)    138871.0
# 3      Never Too Far (Too Far, #2)     97616.0
# 4          The Orphan Master's Son     52765.0
# ...                            ...         ...
# 1042               Sophie's Choice     66923.0
# 1043  é»’åŸ·äº‹ I [Kuroshitsuji I]     74378.0
# 1044                   White Teeth     82474.0
# 1045    Ø§Ù„Ø£Ø³ÙˆØ¯ ÙŠÙ„ÙŠÙ‚ Ø¨Ùƒ     42958.0
# 1046       Ø§Ù„ÙÙŠÙ„ Ø§Ù„Ø£Ø²Ø±Ù‚     53187.0
#
# [1047 rows x 3 columns]

# %% [markdown]
# Вывод: Группировка по двум категориальным столбцам и подсчет средних значений числовой переменной может помочь выявить зависимости между переменными.

# %%
count_by_category = dataset.groupby(['Author', 'units sold']).size().reset_index(name='counts')
count_by_category
# Out:
#                                                Author  units sold  counts
# 0                       A.A. Milne, Ernest H. Shepard         108       1
# 1                                     A.S.A. Harrison       28728       1
# 2                                         Abbi Glines         326       1
# 3                                         Abbi Glines       30456       1
# 4                                        Adam Johnson        4320       1
# ...                                               ...         ...     ...
# 1061                                   William Styron        4400       1
# 1062                         Yana Toboso, Tomo Kimura        2889       1
# 1063                                      Zadie Smith        4563       1
# 1064  Ø£Ø­Ù„Ø§Ù… Ù…Ø³ØªØºØ§Ù†Ù…ÙŠ, Ahlam Mosteghanemi        4320       1
# 1065                                Ø£Ø­Ù…Ø¯ Ù…Ø±Ø§Ø¯        2889       1
#
# [1066 rows x 3 columns]

# %% [markdown]
# Вывод: Группировка и подсчет количества записей по двум переменным может помочь понять распределение данных.
